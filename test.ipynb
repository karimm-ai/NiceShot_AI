# %%
from ultralytics import YOLO

model = YOLO("yolov8n-cod_bo6.pt")
model.export(format="onnx", opset=12, dynamic=True)
# Out:
# Ultralytics 8.3.55  Python-3.11.0 torch-2.5.1+cu121 CPU (Intel Core(TM) i7-10750H 2.60GHz)
# Model summary (fused): 168 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'yolov8n-cod_bo6.pt' with input shape (1, 3, 1920, 1920) BCHW and output shape(s) (1, 7, 75600) (6.2 MB)
#
# ONNX: starting export with onnx 1.19.1 opset 12...
# ONNX: slimming with onnxslim 0.1.73...
# ONNX: export success  6.0s, saved as 'yolov8n-cod_bo6.onnx' (12.2 MB)
#
# Export complete (7.8s)
# Results saved to E:\NiceShot AI\classes\NiceShot_AI
# Predict:         yolo predict task=detect model=yolov8n-cod_bo6.onnx imgsz=1920
# Validate:        yolo val task=detect model=yolov8n-cod_bo6.onnx imgsz=1920 data=data.yaml
# Visualize:       https://netron.app
# 'yolov8n-cod_bo6.onnx'

# %%
import json

with open("E:/NiceShot AI/classes/NiceShot_AI/Clients/events_temp.json", 'r') as f:
    events = json.load(f)

# %%
len(events)
# Out:
# 180

# %%
events = [event for event in events if event["type"] != 'KILL']

# %%
len(events)
# Out:
# 99

# %%
events
# Out:
# [{'type': 'DEATH',
#   'timestart': 580.8333333333334,
#   'timeend': 582.8333333333334,
#   'timestamp': '00.09.40',
#   'desc': 'DEATH@00.09.40.mp4'},
#  {'type': 'DEATH',
#   'timestart': 581.3333333333334,
#   'timeend': 589.8333333333334,
#   'timestamp': '00.09.41',
#   'desc': 'DEATH@00.09.41.mp4'},
#  {'type': 'DEATH',
#   'timestart': 588.3333333333334,
#   'timeend': 592.6666666666666,
#   'timestamp': '00.09.48',
#   'desc': 'DEATH@00.09.48.mp4'},
#  {'type': 'DEATH',
#   'timestart': 597.1666666666666,
#   'timeend': 610.5,
#   'timestamp': '00.09.57',
#   'desc': 'DEATH@00.09.57.mp4'},
#  {'type': 'DEATH',
#   'timestart': 615.6666666666666,
#   'timeend': 629.1666666666666,
#   'timestamp': '00.10.15',
#   'desc': 'DEATH@00.10.15.mp4'},
#  {'type': 'DEATH',
#   'timestart': 635.8333333333334,
#   'timeend': 649.1666666666666,
#   'timestamp': '00.10.35',
#   'desc': 'DEATH@00.10.35.mp4'},
#  {'type': 'DEATH',
#   'timestart': 649.0,
#   'timeend': 662.3333333333334,
# ...
